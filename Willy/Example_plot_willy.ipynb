# %%
from BeamAnalysis import BeamAnalysis
# %matplotlib widget
NEC_dir_path = (
    '/Users/Shared/Files From c.localized/Gabriel_UniBern_Local/DataAnalysis/Low cost THz Camera/20250603/NEC_PowerSeries/all_measurements')
filename = '50 degrees.csv'
NEC_beam_analysis = BeamAnalysis(dir_path=NEC_dir_path,
                                 signal_filename=filename,
                                 camera_name='NEC')
NEC_beam_analysis.plot_map_in_pixels()
nec_map_array = NEC_beam_analysis.map_array

# %%
from BeamAnalysis import BeamAnalysis
# %matplotlib widget
HIKMICRO_dir_path = (
    '/Users/Shared/Files From c.localized/Gabriel_UniBern_Local/Scripts/IR_Camera_Beam_Analyzer/data')
filename = 'triangle.csv'
HIKMICRO_beam_analysis = BeamAnalysis(dir_path=HIKMICRO_dir_path,
                                 signal_filename=filename,
                                      background_filename='triangle_background.csv',
                                 camera_name='HIKMICRO')
HIKMICRO_beam_analysis.plot_map_in_pixels()
HIKMICRO_map_array = NEC_beam_analysis.map_array
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
