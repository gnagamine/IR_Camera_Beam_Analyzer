# %%
import pandas as pd
from Code_utilities.DataPlotter import DataPlotter
import matplotlib.pyplot as plt

plt.close('all')

# %matplotlib widget


datapath = '/Users/Shared/Files From c.localized/Gabriel_UniBern_Local/Manuscripts/Low THz Camera MS/spectral dependecy calculation.csv'
data_df = pd.read_csv(datapath,
                      skiprows=0, )
Plot = DataPlotter()
fig, ax = Plot.plot_relative_responsivity_vs_cutoff(x=data_df['cutoff'],
                                                    y=data_df['HIK ratio norm'] * 100,
                                                    label='IR Camera')
fig, ax = Plot.plot_relative_responsivity_vs_cutoff(x=data_df['cutoff'],
                                                    y=data_df['NEC ration norm'] * 100,
                                                    label='THz Camera',
                                                    ax=ax,
                                                    fig=fig)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
