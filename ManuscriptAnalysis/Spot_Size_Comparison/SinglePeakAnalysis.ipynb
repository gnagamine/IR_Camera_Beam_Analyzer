# %%
from Code_utilities.BeamAnalysis import BeamAnalysis
from FWHMExtractor import FWHMExtractor
# %matplotlib widget

dir_path_HIKMICRO_new = '/Users/Shared/Files From c.localized/Gabriel_UniBern_Local/DataAnalysis/Low cost THz Camera/20250603/PositionSeriesHIKMICRO'
filename = '9,25 mm.csv'
x_center = 151
y_center = 123
width = 100
crop_x_range = (x_center - width/2, x_center + width/2)
crop_y_range = (y_center - width/2, y_center + width/2)
beam_analysis = BeamAnalysis(dir_path=dir_path_HIKMICRO_new,
                             signal_filename=filename,
                             camera_name='HIKMICRO',
                             crop_range_x_pixels=crop_x_range,
                             crop_range_y_pixels=crop_y_range)
fig_HIKMICRO, ax_HIKMICRO = beam_analysis.plot_map_in_pixels()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib widget
map_array = beam_analysis.map_array
fhwm_extractor = FWHMExtractor(map_array=map_array,
                               camera_name='HIKMICRO')
fig_fwhm_extractor, axs_fwhm_extractor = fhwm_extractor.plot_analysis()
fig_fwhm_extractor.set_size_inches(13, 5)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
from Code_utilities.BeamAnalysis import BeamAnalysis
from FWHMExtractor import FWHMExtractor
# %matplotlib widget

dir_path_NEC_new = '/Users/Shared/Files From c.localized/Gabriel_UniBern_Local/DataAnalysis/Low cost THz Camera/20250603/NEC_PositionSeries/all_measurements'
filename = '1,00 mm.csv'
x_center = 129
y_center = 223
width = 50
crop_x_range = (x_center - width/2, x_center + width/2)
crop_y_range = (y_center - width/2, y_center + width/2)
beam_analysis_NEC = BeamAnalysis(dir_path=dir_path_NEC_new,
                             signal_filename=filename,
                             camera_name='NEC',
                             crop_range_x_pixels=crop_x_range,
                             crop_range_y_pixels=crop_y_range)
fig_HIKMICRO, ax_HIKMICRO = beam_analysis_NEC.plot_map_in_pixels()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib widget
map_array_NEC = beam_analysis_NEC.map_array
fhwm_extractor_NEC = FWHMExtractor(map_array=map_array_NEC,
                               camera_name='NEC',
                               Y_ref_position_for_background_subtraction=10)
fig_fwhm_extractor_NEC, axs_fwhm_extractor_NEC = fhwm_extractor_NEC.plot_analysis()
fig_fwhm_extractor_NEC.set_size_inches(13, 5)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
